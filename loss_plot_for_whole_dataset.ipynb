# %%
import matplotlib.pyplot as plt
import pandas as pd
import os

# Specify the path of the input file
input_file_path = '/home/raj/Rajarshi/Term Project/rajarshi_code/itransformer_file/epoch_loss_log_one_window_itransformer_model.txt'

# Load the data from the file
loss_data = pd.read_csv(input_file_path)

# Print the DataFrame to check if it's loaded correctly
print(loss_data)

# Specify the folder where you want to save the plots
output_folder = '/home/raj/Rajarshi/Term Project/notebook_files/saved_plots/loss_plots'

# Ensure the folder exists; if not, create it
os.makedirs(output_folder, exist_ok=True)

# Extract the base filename from the input file path without the extension
base_filename = os.path.splitext(os.path.basename(input_file_path))[0]

# Create a figure and axis for plotting
plt.figure(figsize=(10, 6))

# Plot the loss values across all epochs
plt.plot(loss_data['Epoch'], loss_data['Train_Loss'], marker='o', linestyle='-', label='Training Loss')

# Add titles and labels
plt.title('Training Loss Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Train Loss')
plt.legend(loc='upper right', fontsize='medium')
plt.grid(True)

# Save the plot using the extracted base filename
filename = f'{base_filename}_train_loss.png'
plt.savefig(os.path.join(output_folder, filename), format='png', dpi=300)

# Show the plot
plt.show()
# Out:
#      Epoch  Train_Loss
# 0        0    0.022814
# 1        1    0.047117
# 2        2    0.038936
# 3        3    0.024873
# 4        4    0.032589
# ..     ...         ...
# 995    995    0.007754
# 996    996    0.009964
# 997    997    0.010806
# 998    998    0.015011
# 999    999    0.012188
#
# [1000 rows x 2 columns]
